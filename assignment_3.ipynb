# %% [markdown]
# # Noah Grimes Assignment 3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Question 9 in §2.4

# %%
df_auto = pd.read_csv("/Users/noah/Documents/SEU/data_science/ALL CSV FILES - 2nd Edition/Auto.csv")

# %%
df_auto.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year
# 0  18.0          8         307.0        130    3504          12.0    70  \
# 1  15.0          8         350.0        165    3693          11.5    70
# 2  18.0          8         318.0        150    3436          11.0    70
# 3  16.0          8         304.0        150    3433          12.0    70
# 4  17.0          8         302.0        140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# ## A)

# %% [markdown]
# ### Quantitative
# - mpg
# - cylinders
# - displacement
# - horsepower
# - weight
# - acceleration
# - year
# - origin

# %% [markdown]
# ### Qualititative
# - name

# %% [markdown]
# ## B)

# %%
df_auto.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration
# count  397.000000  397.000000    397.000000   397.000000    397.000000  \
# mean    23.515869    5.458438    193.532746  2970.261965     15.555668
# std      7.825804    1.701577    104.379583   847.904119      2.749995
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.000000  2223.000000     13.800000
# 50%     23.000000    4.000000    146.000000  2800.000000     15.500000
# 75%     29.000000    8.000000    262.000000  3609.000000     17.100000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#              year      origin
# count  397.000000  397.000000
# mean    75.994962    1.574307
# std      3.690005    0.802549
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
quant_columns = df_auto.select_dtypes(include=['number'])

# %%
ranges = quant_columns.max() - quant_columns.min()
print(ranges)
# Out:
# mpg               37.6
# cylinders          5.0
# displacement     387.0
# weight          3527.0
# acceleration      16.8
# year              12.0
# origin             2.0
# dtype: float64

# %% [markdown]
# ## C)

# %%
mean = quant_columns.mean()
std_devs = quant_columns.std()
# Out:
# Mean:
# mpg               23.515869
# cylinders          5.458438
# displacement     193.532746
# weight          2970.261965
# acceleration      15.555668
# year              75.994962
# origin             1.574307
# dtype: float64
#
# Standard Deviation:
# mpg               7.825804
# cylinders         1.701577
# displacement    104.379583
# weight          847.904119
# acceleration      2.749995
# year              3.690005
# origin            0.802549
# dtype: float64

# %%
print("Mean:")
print(mean)
print("\nStandard Deviation:")
print(std_devs)
# Out:
# Mean:
# mpg               23.515869
# cylinders          5.458438
# displacement     193.532746
# weight          2970.261965
# acceleration      15.555668
# year              75.994962
# origin             1.574307
# dtype: float64
#
# Standard Deviation:
# mpg               7.825804
# cylinders         1.701577
# displacement    104.379583
# weight          847.904119
# acceleration      2.749995
# year              3.690005
# origin            0.802549
# dtype: float64

# %% [markdown]
# ## D)

# %%
df_auto_subset = df_auto.drop(df_auto.index[10:86])

# %%
df_auto_subset
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year
# 0    18.0          8         307.0        130    3504          12.0    70  \
# 1    15.0          8         350.0        165    3693          11.5    70
# 2    18.0          8         318.0        150    3436          11.0    70
# 3    16.0          8         304.0        150    3433          12.0    70
# 4    17.0          8         302.0        140    3449          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0         86    2790          15.6    82
# 393  44.0          4          97.0         52    2130          24.6    82
# 394  32.0          4         135.0         84    2295          11.6    82
# 395  28.0          4         120.0         79    2625          18.6    82
# 396  31.0          4         119.0         82    2720          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# ...

# %%
quant_columns_subset = df_auto_subset.select_dtypes(include=['number'])

# %%
range_subset = quant_columns_subset.max() - quant_columns_subset.min()
mean_subset = quant_columns_subset.mean()
std_devs_subset = quant_columns_subset.std()

# %%
print("Range:")
print(range_subset)
print("\nMean:")
print(mean_subset)
print("\nStandard Deviation:")
print(std_devs_subset)
# Out:
# Range:
# mpg               35.6
# cylinders          5.0
# displacement     387.0
# weight          3348.0
# acceleration      16.3
# year              12.0
# origin             2.0
# dtype: float64
#
# Mean:
# mpg               24.444860
# cylinders          5.370717
# displacement     187.174455
# weight          2933.183801
# acceleration      15.709034
# year              77.143302
# origin             1.598131
# dtype: float64
#
# Standard Deviation:
# mpg               7.899928
# cylinders         1.653486
# displacement     99.864568
# weight          809.638650
# acceleration      2.706441
# year              3.128202
# origin            0.816163
# dtype: float64

# %% [markdown]
# ## E)

# %%
plt.scatter(df_auto['cylinders'], df_auto['mpg'])
plt.xlabel('Cylinders')
plt.ylabel('MPG')
plt.title('MPG vs. Cylinders')
plt.show()

# %%
plt.scatter(df_auto['cylinders'], df_auto['displacement'])
plt.xlabel('Cylinders')
plt.ylabel('Displacement')
plt.title('Cylinders vs. Displacement')
plt.show()

# %%
sns.histplot(data=df_auto, x='mpg', bins=15, kde=True)
plt.xlabel('MPG')
plt.ylabel('Count')
plt.title('Frequency of MPG')
plt.show()

# %%
sns.countplot(x='cylinders', data=df_auto)
plt.xlabel('Number of Cylinders')
plt.ylabel('Count')
plt.title('Cylinder Counts')
plt.show()

# %% [markdown]
# ## F)

# %%
sns.pairplot(df_auto, x_vars=['cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year', 'origin'], y_vars=['mpg'], kind='scatter')
plt.show()

# %% [markdown]
# #### - Displacement, weight, cylinders, acceleration, and year show predictive insight into the MPG of a car

# %% [markdown]
# # Question 10 in §2.4

# %% [markdown]
# ## A)

# %%
df_boston = pd.read_csv("/Users/noah/Documents/SEU/data_science/ALL CSV FILES - 2nd Edition/Boston.csv", index_col=0)

# %%
df_boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio
# 1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3  \
# 2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    lstat  medv
# 1   4.98  24.0
# 2   9.14  21.6
# 3   4.03  34.7
# 4   2.94  33.4
# 5   5.33  36.2

# %% [markdown]
# 1. crim: per capita crime rate by town.
# 2. zn: proportion of residential land zoned for lots over 25,000 sq.ft.
# 3. indus: proportion of non-retail business acres per town.
# 4. chas: Charles River dummy variable (= 1 if tract bounds river; 0 otherwise).
# 5. nox: nitrogen oxides concentration (parts per 10 million).
# 7. rm: average number of rooms per dwelling.
# 8. age: proportion of owner-occupied units built prior to 1940.
# 9. dis: weighted mean of distances to five Boston employment centres.
# 10. rad: index of accessibility to radial highways.
# 11. tax: full-value property-tax rate per dollar 10,000.
# 12. ptratio: pupil-teacher ratio by town.
# 13. lstat: lower status of the population (percent).
# 14. medv: median value of owner-occupied homes in $1000s.

# %% [markdown]
# ## B)

# %%
df_boston.shape
# Out:
# (506, 13)

# %% [markdown]
# - 506 Rows
# - 13 columns

# %% [markdown]
# ## C)

# %%
sns.pairplot(df_boston)
plt.show()

# %% [markdown]
# - There are some linear and nonlinear relationships
# - Several of the varaibles associate with crime rate

# %% [markdown]
# ## D)

# %% [markdown]
# crime rate relates with
# - age, distance, index of accessibility to radial highways, tax, lower status of the population (percent), and median value of owner-occupied homes in $1000s.

# %% [markdown]
# ## E)

# %%
new_df = df_boston[['crim', 'tax', 'ptratio']]
range_num_vars = new_df.apply(lambda x: (x.min(), x.max()))
print(range_num_vars)
# Out:
#        crim  tax  ptratio
# 0   0.00632  187     12.6
# 1  88.97620  711     22.0

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4))
new_df['crim'].plot.hist(bins=10, ax=axes[0], color='blue')
new_df['tax'].plot.hist(bins=10, ax=axes[1], color='red')
new_df['ptratio'].plot.hist(bins=10, ax=axes[2], color='green')

axes[0].set_title('crim')
axes[1].set_title('tax')
axes[2].set_title('ptratio')


plt.show()

# %% [markdown]
# ## F)

# %%
(df_boston['chas'] == 1).sum()
# Out:
# 35

# %% [markdown]
# ## G)

# %%
df_boston['ptratio'].median()
# Out:
# 19.05

# %% [markdown]
# ## H)

# %%
df_boston[df_boston['medv'] == df_boston['medv'].min()]
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax
# 399  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666  \
# 406  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
#
#      ptratio  lstat  medv
# 399     20.2  30.59   5.0
# 406     20.2  22.98   5.0

# %%
df_boston.describe()
# Out:
#              crim          zn       indus        chas         nox          rm
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000  \
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       lstat
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000  \
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %% [markdown]
# - Suburb #399 crime is very high compared to median rates of all other suburbs

# %% [markdown]
# ## I)

# %%
(df_boston['rm'] > 7).sum()
# Out:
# 64

# %%
(df_boston['rm'] > 8).sum()
# Out:
# 13

# %%
df_boston_rm_8 = df_boston[df_boston['rm'] > 8]
df_boston_rm_8.describe()
# Out:
#             crim         zn      indus       chas        nox         rm
# count  13.000000  13.000000  13.000000  13.000000  13.000000  13.000000  \
# mean    0.718795  13.615385   7.078462   0.153846   0.539238   8.348538
# std     0.901640  26.298094   5.392767   0.375534   0.092352   0.251261
# min     0.020090   0.000000   2.680000   0.000000   0.416100   8.034000
# 25%     0.331470   0.000000   3.970000   0.000000   0.504000   8.247000
# 50%     0.520140   0.000000   6.200000   0.000000   0.507000   8.297000
# 75%     0.578340  20.000000   6.200000   0.000000   0.605000   8.398000
# max     3.474280  95.000000  19.580000   1.000000   0.718000   8.780000
#
#              age        dis        rad         tax    ptratio      lstat
# count  13.000000  13.000000  13.000000   13.000000  13.000000  13.000000  \
# mean   71.538462   3.430192   7.461538  325.076923  16.361538   4.310000
# std    24.608723   1.883955   5.332532  110.971063   2.410580   1.373566
# ...
